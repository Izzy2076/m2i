# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

spark = SparkSession.builder.master("local").getOrCreate()
sc = spark.sparkContext

# %%
movies_df = spark.read.options(header=True, inferSchema=True, sep=",").csv("../Data/movies.csv")
ratings_df = spark.read.options(header=True, inferSchema=True, sep=",").csv("../Data/ratings.csv")

print(movies_df.count())
print(ratings_df.count())
# Out:
# 9742
# 100836

# %%
# Inner join
df = ratings_df.join(movies_df, "movieId", "inner")

df.show()
# Out:
# +-------+------+------+---------+--------------------+--------------------+
# |movieId|userId|rating|timestamp|               title|              genres|
# +-------+------+------+---------+--------------------+--------------------+
# |      1|     1|   4.0|964982703|    Toy Story (1995)|Adventure|Animati...|
# |      3|     1|   4.0|964981247|Grumpier Old Men ...|      Comedy|Romance|
# |      6|     1|   4.0|964982224|         Heat (1995)|Action|Crime|Thri...|
# |     47|     1|   5.0|964983815|Seven (a.k.a. Se7...|    Mystery|Thriller|
# |     50|     1|   5.0|964982931|Usual Suspects, T...|Crime|Mystery|Thr...|
# |     70|     1|   3.0|964982400|From Dusk Till Da...|Action|Comedy|Hor...|
# |    101|     1|   5.0|964980868|Bottle Rocket (1996)|Adventure|Comedy|...|
# |    110|     1|   4.0|964982176|   Braveheart (1995)|    Action|Drama|War|
# |    151|     1|   5.0|964984041|      Rob Roy (1995)|Action|Drama|Roma...|
# |    157|     1|   5.0|964984100|Canadian Bacon (1...|          Comedy|War|
# |    163|     1|   5.0|964983650|    Desperado (1995)|Action|Romance|We...|
# |    216|     1|   5.0|964981208|Billy Madison (1995)|              Comedy|
# |    223|     1|   3.0|964980985|       Clerks (1994)|              Comedy|
# |    231|     1|   5.0|964981179|Dumb & Dumber (Du...|    Adventure|Comedy|
# |    235|     1|   4.0|964980908|      Ed Wood (1994)|        Comedy|Drama|
# |    260|     1|   5.0|964981680|Star Wars: Episod...|Action|Adventure|...|
# |    296|     1|   3.0|964982967| Pulp Fiction (1994)|Comedy|Crime|Dram...|
# |    316|     1|   3.0|964982310|     Stargate (1994)|Action|Adventure|...|
# |    333|     1|   5.0|964981179|    Tommy Boy (1995)|              Comedy|
# |    349|     1|   4.0|964982563|Clear and Present...|Action|Crime|Dram...|
# +-------+------+------+---------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Calculer le nombre de notes et la moyenne des notes par film
# Trier par nombre de notes décroissant
ratings_df.groupBy("movieId").agg(
    count("rating").alias("nb_rating"),
    avg("rating").alias("avg_rating")
).join(movies_df, "movieId", "inner").orderBy(desc("nb_rating")).show()
# Out:
# +-------+---------+------------------+--------------------+--------------------+
# |movieId|nb_rating|        avg_rating|               title|              genres|
# +-------+---------+------------------+--------------------+--------------------+
# |    356|      329| 4.164133738601824| Forrest Gump (1994)|Comedy|Drama|Roma...|
# |    318|      317| 4.429022082018927|Shawshank Redempt...|         Crime|Drama|
# |    296|      307| 4.197068403908795| Pulp Fiction (1994)|Comedy|Crime|Dram...|
# |    593|      279| 4.161290322580645|Silence of the La...|Crime|Horror|Thri...|
# |   2571|      278| 4.192446043165468|  Matrix, The (1999)|Action|Sci-Fi|Thr...|
# |    260|      251| 4.231075697211155|Star Wars: Episod...|Action|Adventure|...|
# |    480|      238|              3.75|Jurassic Park (1993)|Action|Adventure|...|
# |    110|      237| 4.031645569620253|   Braveheart (1995)|    Action|Drama|War|
# |    589|      224| 3.970982142857143|Terminator 2: Jud...|       Action|Sci-Fi|
# |    527|      220|             4.225|Schindler's List ...|           Drama|War|
# |   2959|      218| 4.272935779816514|   Fight Club (1999)|Action|Crime|Dram...|
# |      1|      215|3.9209302325581397|    Toy Story (1995)|Adventure|Animati...|
# |   1196|      211|4.2156398104265405|Star Wars: Episod...|Action|Adventure|...|
# |     50|      204| 4.237745098039215|Usual Suspects, T...|Crime|Mystery|Thr...|
# |   2858|      204| 4.056372549019608|American Beauty (...|       Drama|Romance|
# |     47|      203|3.9753694581280787|Seven (a.k.a. Se7...|    Mystery|Thriller|
# |    780|      202|3.4455445544554455|Independence Day ...|Action|Adventure|...|
# |    150|      201| 3.845771144278607|    Apollo 13 (1995)|Adventure|Drama|IMAX|
# |   1198|      200|            4.2075|Raiders of the Lo...|    Action|Adventure|
# |   4993|      198| 4.106060606060606|Lord of the Rings...|   Adventure|Fantasy|
# +-------+---------+------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# **LEFT SEMI** : films qui ont au moins une note
ratings_df.join(movies_df, "movieId", "left_semi").show()
# Out:
# +-------+------+------+---------+
# |movieId|userId|rating|timestamp|
# +-------+------+------+---------+
# |      1|     1|   4.0|964982703|
# |      3|     1|   4.0|964981247|
# |      6|     1|   4.0|964982224|
# |     47|     1|   5.0|964983815|
# |     50|     1|   5.0|964982931|
# |     70|     1|   3.0|964982400|
# |    101|     1|   5.0|964980868|
# |    110|     1|   4.0|964982176|
# |    151|     1|   5.0|964984041|
# |    157|     1|   5.0|964984100|
# |    163|     1|   5.0|964983650|
# |    216|     1|   5.0|964981208|
# |    223|     1|   3.0|964980985|
# |    231|     1|   5.0|964981179|
# |    235|     1|   4.0|964980908|
# |    260|     1|   5.0|964981680|
# |    296|     1|   3.0|964982967|
# |    316|     1|   3.0|964982310|
# |    333|     1|   5.0|964981179|
# |    349|     1|   4.0|964982563|
# +-------+------+------+---------+
# only showing top 20 rows

# %%
# **LEFT ANTI** : films sans aucune note
movies_df.join(ratings_df, "movieId", "left_anti").show()
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |   1076|Innocents, The (1...|Drama|Horror|Thri...|
# |   2939|      Niagara (1953)|      Drama|Thriller|
# |   3338|For All Mankind (...|         Documentary|
# |   3456|Color of Paradise...|               Drama|
# |   4194|I Know Where I'm ...|   Drama|Romance|War|
# |   5721|  Chosen, The (1981)|               Drama|
# |   6668|Road Home, The (W...|       Drama|Romance|
# |   6849|      Scrooge (1970)|Drama|Fantasy|Mus...|
# |   7020|        Proof (1991)|Comedy|Drama|Romance|
# |   7792|Parallax View, Th...|            Thriller|
# |   8765|This Gun for Hire...|Crime|Film-Noir|T...|
# |  25855|Roaring Twenties,...|Crime|Drama|Thriller|
# |  26085|Mutiny on the Bou...|Adventure|Drama|R...|
# |  30892|In the Realms of ...|Animation|Documen...|
# |  32160|Twentieth Century...|              Comedy|
# |  32371|Call Northside 77...|Crime|Drama|Film-...|
# |  34482|Browning Version,...|               Drama|
# |  85565|  Chalet Girl (2011)|      Comedy|Romance|
# +-------+--------------------+--------------------+

# %%
# **LEFT OUTER** : liste complète des films avec stats si disponibles
movies_df.join(ratings_df, "movieId", "left_outer").groupBy("rating").agg(
    count("rating").alias("rating_count"),
    avg("rating").alias("rating_avg"),
).show()
# Out:
# +------+------------+----------+
# |rating|rating_count|rating_avg|
# +------+------------+----------+
# |   3.5|       13136|       3.5|
# |   4.5|        8551|       4.5|
# |  NULL|           0|      NULL|
# |   2.5|        5550|       2.5|
# |   1.0|        2811|       1.0|
# |   4.0|       26818|       4.0|
# |   0.5|        1370|       0.5|
# |   3.0|       20047|       3.0|
# |   2.0|        7551|       2.0|
# |   1.5|        1791|       1.5|
# |   5.0|       13211|       5.0|
# +------+------------+----------+

# %%
diagnostic = movies_df.join(ratings_df, "movieId", "full")
diagnostic.show()

# MovieId présent uniquement dans ratings
movie_without_ratings = diagnostic.filter(col("title").isNull())
movie_without_ratings.count()
# Out:
# +-------+----------------+--------------------+------+------+----------+
# |movieId|           title|              genres|userId|rating| timestamp|
# +-------+----------------+--------------------+------+------+----------+
# |      1|Toy Story (1995)|Adventure|Animati...|     1|   4.0| 964982703|
# |      1|Toy Story (1995)|Adventure|Animati...|     5|   4.0| 847434962|
# |      1|Toy Story (1995)|Adventure|Animati...|     7|   4.5|1106635946|
# |      1|Toy Story (1995)|Adventure|Animati...|    15|   2.5|1510577970|
# |      1|Toy Story (1995)|Adventure|Animati...|    17|   4.5|1305696483|
# |      1|Toy Story (1995)|Adventure|Animati...|    18|   3.5|1455209816|
# |      1|Toy Story (1995)|Adventure|Animati...|    19|   4.0| 965705637|
# |      1|Toy Story (1995)|Adventure|Animati...|    21|   3.5|1407618878|
# |      1|Toy Story (1995)|Adventure|Animati...|    27|   3.0| 962685262|
# |      1|Toy Story (1995)|Adventure|Animati...|    31|   5.0| 850466616|
# |      1|Toy Story (1995)|Adventure|Animati...|    32|   3.0| 856736119|
# |      1|Toy Story (1995)|Adventure|Animati...|    33|   3.0| 939647444|
# |      1|Toy Story (1995)|Adventure|Animati...|    40|   5.0| 832058959|
# |      1|Toy Story (1995)|Adventure|Animati...|    43|   5.0| 848993983|
# |      1|Toy Story (1995)|Adventure|Animati...|    44|   3.0| 869251860|
# |      1|Toy Story (1995)|Adventure|Animati...|    45|   4.0| 951170182|
# |      1|Toy Story (1995)|Adventure|Animati...|    46|   5.0| 834787906|
# |      1|Toy Story (1995)|Adventure|Animati...|    50|   3.0|1514238116|
# |      1|Toy Story (1995)|Adventure|Animati...|    54|   3.0| 830247330|
# |      1|Toy Story (1995)|Adventure|Animati...|    57|   5.0| 965796031|
# +-------+----------------+--------------------+------+------+----------+
# only showing top 20 rows
# 0

# %%
from pyspark.sql.window import Window

# A. **Top 5 global** : films les mieux notés
ratings_df.groupBy('movieId').agg(
    count("rating").alias("rating_nb"),
    avg("rating").alias("avg_rating")
).filter(col("rating_nb") >= 50).join(movies_df, "movieId").orderBy(desc("avg_rating")).show(5)
# B. **Top 10 par genre** : films les mieux notés par genre
movies_exploded = movies_df.select("movieId", "title", explode(split(col("genres"), "\\|")).alias("genre"))
window = Window.partitionBy("genre").orderBy(desc("avg_rating"))

df_with_genres = ratings_df.groupBy("movieId").agg(
    count("rating").alias("nb_ratings"),
    avg("rating").alias("avg_rating")
).join(movies_exploded, "movieId").filter(col("nb_ratings") >= 50)

df_with_genres.withColumn("rank", row_number().over(window)).orderBy("genre", "rank").filter(col("rank") <= 10).show(100)
# C. **Moyenne annuelle** : moyenne des notes par année de sortie  
movies_year = movies_df.withColumn("year", regexp_extract(col("title"), r"\((\d{4})\)", 1).cast("int"))
ratings_df.join(movies_year, "movieId").groupBy("year").agg(
    count("rating").alias("nb_rating"),
    avg("rating").alias("avg_rating")
).filter(col("nb_rating") >= 50).orderBy("year").show()
# Out:
# +-------+---------+-----------------+--------------------+--------------------+
# |movieId|rating_nb|       avg_rating|               title|              genres|
# +-------+---------+-----------------+--------------------+--------------------+
# |    318|      317|4.429022082018927|Shawshank Redempt...|         Crime|Drama|
# |    858|      192|        4.2890625|Godfather, The (1...|         Crime|Drama|
# |   2959|      218|4.272935779816514|   Fight Club (1999)|Action|Crime|Dram...|
# |   1276|       57|4.271929824561403|Cool Hand Luke (1...|               Drama|
# |    750|       97|4.268041237113402|Dr. Strangelove o...|          Comedy|War|
# +-------+---------+-----------------+--------------------+--------------------+
# only showing top 5 rows
#
# +-------+----------+------------------+--------------------+-----------+----+
# |movieId|nb_ratings|        avg_rating|               title|      genre|rank|
# +-------+----------+------------------+--------------------+-----------+----+
# |   2959|       218| 4.272935779816514|   Fight Club (1999)|     Action|   1|
# |  58559|       149| 4.238255033557047|Dark Knight, The ...|     Action|   2|
# |   1197|       142| 4.232394366197183|Princess Bride, T...|     Action|   3|
# |    260|       251| 4.231075697211155|Star Wars: Episod...|     Action|   4|
# |   1208|       107| 4.219626168224299|Apocalypse Now (1...|     Action|   5|
# |   1196|       211|4.2156398104265405|Star Wars: Episod...|     Action|   6|
# |   1198|       200|            4.2075|Raiders of the Lo...|     Action|   7|
# |   2571|       278| 4.192446043165468|  Matrix, The (1999)|     Action|   8|
# |    908|        57| 4.184210526315789|North by Northwes...|     Action|   9|
# |   6016|        75|4.1466666666666665|City of God (Cida...|     Action|  10|
# |   1197|       142| 4.232394366197183|Princess Bride, T...|  Adventure|   1|
# |    260|       251| 4.231075697211155|Star Wars: Episod...|  Adventure|   2|
# |   1196|       211|4.2156398104265405|Star Wars: Episod...|  Adventure|   3|
# |   1198|       200|            4.2075|Raiders of the Lo...|  Adventure|   4|
# |    908|        57| 4.184210526315789|North by Northwes...|  Adventure|   5|
# |   1136|       136| 4.161764705882353|Monty Python and ...|  Adventure|   6|
# |   5618|        87| 4.155172413793103|Spirited Away (Se...|  Adventure|   7|
# |   6016|        75|4.1466666666666665|City of God (Cida...|  Adventure|   8|
# |   1201|        72| 4.145833333333333|Good, the Bad and...|  Adventure|   9|
# |   1210|       196| 4.137755102040816|Star Wars: Episod...|  Adventure|  10|
# |   5618|        87| 4.155172413793103|Spirited Away (Se...|  Animation|   1|
# |  78499|        55| 4.109090909090909|  Toy Story 3 (2010)|  Animation|   2|
# |  60069|       104|4.0576923076923075|       WALL·E (2008)|  Animation|   3|
# |   1148|        56| 4.035714285714286|Wallace & Gromit:...|  Animation|   4|
# |  68954|       105| 4.004761904761905|           Up (2009)|  Animation|   5|
# |   6377|       141|3.9609929078014185| Finding Nemo (2003)|  Animation|   6|
# |  76093|        53| 3.943396226415094|How to Train Your...|  Animation|   7|
# |    364|       172| 3.941860465116279|Lion King, The (1...|  Animation|   8|
# |      1|       215|3.9209302325581397|    Toy Story (1995)|  Animation|   9|
# |   4886|       132| 3.871212121212121|Monsters, Inc. (2...|  Animation|  10|
# |  78499|        55| 4.109090909090909|  Toy Story 3 (2010)|   Children|   1|
# |  60069|       104|4.0576923076923075|       WALL·E (2008)|   Children|   2|
# |   1148|        56| 4.035714285714286|Wallace & Gromit:...|   Children|   3|
# |    953|        58|4.0344827586206895|It's a Wonderful ...|   Children|   4|
# |  68954|       105| 4.004761904761905|           Up (2009)|   Children|   5|
# |   2804|        55|3.9727272727272727|Christmas Story, ...|   Children|   6|
# |   6377|       141|3.9609929078014185| Finding Nemo (2003)|   Children|   7|
# |  76093|        53| 3.943396226415094|How to Train Your...|   Children|   8|
# |    364|       172| 3.941860465116279|Lion King, The (1...|   Children|   9|
# |      1|       215|3.9209302325581397|    Toy Story (1995)|   Children|  10|
# |    750|        97| 4.268041237113402|Dr. Strangelove o...|     Comedy|   1|
# |   1197|       142| 4.232394366197183|Princess Bride, T...|     Comedy|   2|
# |    296|       307| 4.197068403908795| Pulp Fiction (1994)|     Comedy|   3|
# |   4973|       120| 4.183333333333334|Amelie (Fabuleux ...|     Comedy|   4|
# |    356|       329| 4.164133738601824| Forrest Gump (1994)|     Comedy|   5|
# |   1136|       136| 4.161764705882353|Monty Python and ...|     Comedy|   6|
# |   4011|        93| 4.155913978494624|       Snatch (2000)|     Comedy|   7|
# |   2324|        88|4.1477272727272725|Life Is Beautiful...|     Comedy|   8|
# |    608|       181| 4.116022099447513|        Fargo (1996)|     Comedy|   9|
# |  78499|        55| 4.109090909090909|  Toy Story 3 (2010)|     Comedy|  10|
# |    318|       317| 4.429022082018927|Shawshank Redempt...|      Crime|   1|
# |    858|       192|         4.2890625|Godfather, The (1...|      Crime|   2|
# |   2959|       218| 4.272935779816514|   Fight Club (1999)|      Crime|   3|
# |   1221|       129|  4.25968992248062|Godfather: Part I...|      Crime|   4|
# |  48516|       107| 4.252336448598131|Departed, The (2006)|      Crime|   5|
# |   1213|       126|              4.25|   Goodfellas (1990)|      Crime|   6|
# |  58559|       149| 4.238255033557047|Dark Knight, The ...|      Crime|   7|
# |     50|       204| 4.237745098039215|Usual Suspects, T...|      Crime|   8|
# |   2329|       129| 4.217054263565892|American History ...|      Crime|   9|
# |   1252|        59| 4.211864406779661|    Chinatown (1974)|      Crime|  10|
# |   5669|        58|3.7758620689655173|Bowling for Colum...|Documentary|   1|
# |   8464|        50|              3.51|Super Size Me (2004)|Documentary|   2|
# |    318|       317| 4.429022082018927|Shawshank Redempt...|      Drama|   1|
# |    858|       192|         4.2890625|Godfather, The (1...|      Drama|   2|
# |   2959|       218| 4.272935779816514|   Fight Club (1999)|      Drama|   3|
# |   1276|        57| 4.271929824561403|Cool Hand Luke (1...|      Drama|   4|
# |   1221|       129|  4.25968992248062|Godfather: Part I...|      Drama|   5|
# |  48516|       107| 4.252336448598131|Departed, The (2006)|      Drama|   6|
# |   1213|       126|              4.25|   Goodfellas (1990)|      Drama|   7|
# |    912|       100|              4.24|   Casablanca (1942)|      Drama|   8|
# |  58559|       149| 4.238255033557047|Dark Knight, The ...|      Drama|   9|
# |    527|       220|             4.225|Schindler's List ...|      Drama|  10|
# |   1197|       142| 4.232394366197183|Princess Bride, T...|    Fantasy|   1|
# |   1199|        59| 4.177966101694915|       Brazil (1985)|    Fantasy|   2|
# |   1136|       136| 4.161764705882353|Monty Python and ...|    Fantasy|   3|
# |   5618|        87| 4.155172413793103|Spirited Away (Se...|    Fantasy|   4|
# |   7153|       185| 4.118918918918919|Lord of the Rings...|    Fantasy|   5|
# |  78499|        55| 4.109090909090909|  Toy Story 3 (2010)|    Fantasy|   6|
# |   4993|       198| 4.106060606060606|Lord of the Rings...|    Fantasy|   7|
# |   1215|        51|  4.03921568627451|Army of Darkness ...|    Fantasy|   8|
# |    953|        58|4.0344827586206895|It's a Wonderful ...|    Fantasy|   9|
# |   5952|       188|4.0212765957446805|Lord of the Rings...|    Fantasy|  10|
# |   1252|        59| 4.211864406779661|    Chinatown (1974)|  Film-Noir|   1|
# |   1617|        97| 4.061855670103093|L.A. Confidential...|  Film-Noir|   2|
# |  32587|        84| 3.857142857142857|     Sin City (2005)|  Film-Noir|   3|
# |   4848|        51| 3.843137254901961|Mulholland Drive ...|  Film-Noir|   4|
# |    593|       279| 4.161290322580645|Silence of the La...|     Horror|   1|
# |   1258|       109|  4.08256880733945| Shining, The (1980)|     Horror|   2|
# |   1215|        51|  4.03921568627451|Army of Darkness ...|     Horror|   3|
# |   1219|        83| 4.036144578313253|       Psycho (1960)|     Horror|   4|
# |   8874|        77|4.0064935064935066|Shaun of the Dead...|     Horror|   5|
# |   1387|        91|4.0054945054945055|         Jaws (1975)|     Horror|   6|
# |   6502|        58|3.9741379310344827|28 Days Later (2002)|     Horror|   7|
# |   1214|       146| 3.969178082191781|        Alien (1979)|     Horror|   8|
# |   1200|       126|3.9642857142857144|       Aliens (1986)|     Horror|   9|
# |   2762|       179| 3.893854748603352|Sixth Sense, The ...|     Horror|  10|
# |  58559|       149| 4.238255033557047|Dark Knight, The ...|       IMAX|   1|
# |  78499|        55| 4.109090909090909|  Toy Story 3 (2010)|       IMAX|   2|
# |  79132|       143| 4.066433566433567|    Inception (2010)|       IMAX|   3|
# |  91529|        76|3.9934210526315788|Dark Knight Rises...|       IMAX|   4|
# +-------+----------+------------------+--------------------+-----------+----+
# only showing top 100 rows
#
# +----+---------+------------------+
# |year|nb_rating|        avg_rating|
# +----+---------+------------------+
# |1931|       76|3.6052631578947367|
# |1933|       65| 3.730769230769231|
# |1936|       53|3.5283018867924527|
# |1937|      115|3.6608695652173915|
# |1938|       56| 3.767857142857143|
# |1939|      201| 3.763681592039801|
# |1940|      223| 3.818385650224215|
# |1941|      197|3.8959390862944163|
# |1942|      185|3.9216216216216218|
# |1944|       92| 4.043478260869565|
# |1946|      138| 3.949275362318841|
# |1947|       52|3.8461538461538463|
# |1948|       80|              3.85|
# |1949|       72| 3.763888888888889|
# |1950|      161| 3.813664596273292|
# |1951|      182|3.8049450549450547|
# |1952|       96|          3.953125|
# |1953|      153|3.6470588235294117|
# |1954|      272| 4.009191176470588|
# |1955|      182|  3.71978021978022|
# +----+---------+------------------+
# only showing top 20 rows

# %%
# D. **Profil utilisateur** : genre préféré de chaque utilisateur
user_genre_df = ratings_df.join(movies_exploded, "movieId").groupBy("userId", "genre").agg(
    avg("rating").alias("avg_rating"),
    count("rating").alias("nb_ratings")
).filter(col("nb_ratings") >= 5)

window_user = Window.partitionBy("userId").orderBy(desc("avg_rating"))

user_genre_df.withColumn("rank", row_number().over(window_user)).filter(col("rank") == 1).show()
# Out:
# +------+---------+------------------+----------+----+
# |userId|    genre|        avg_rating|nb_ratings|rank|
# +------+---------+------------------+----------+----+
# |     1|Animation| 4.689655172413793|        29|   1|
# |     2|   Comedy|               4.0|         7|   1|
# |     3|   Horror|            4.6875|         8|   1|
# |     4|Animation|               4.0|         6|   1|
# |     5|  Musical|               4.4|         5|   1|
# |     6|  Musical| 4.166666666666667|        12|   1|
# |     7|   Horror|               4.0|         5|   1|
# |     8|    Crime| 3.888888888888889|         9|   1|
# |     9|Adventure|               3.8|        10|   1|
# |    10|Animation|3.8666666666666667|        15|   1|
# |    11|      War| 4.333333333333333|         6|   1|
# |    12|  Romance| 4.571428571428571|        21|   1|
# |    13|   Action|               4.2|        10|   1|
# |    14|    Drama|3.7083333333333335|        24|   1|
# |    15|      War|               4.1|         5|   1|
# |    16|Film-Noir|               4.0|         5|   1|
# |    17|      War| 4.444444444444445|         9|   1|
# |    18|  Western| 4.181818181818182|        11|   1|
# |    19|Film-Noir|3.3333333333333335|         9|   1|
# |    20|     IMAX|               4.6|         5|   1|
# +------+---------+------------------+----------+----+
# only showing top 20 rows

# %%
# E. **Films sans note** : lister 20 films sans aucune note  
movie_without_ratings.show(20)
# Out:
# +-------+-----+------+------+------+---------+
# |movieId|title|genres|userId|rating|timestamp|
# +-------+-----+------+------+------+---------+
# +-------+-----+------+------+------+---------+

# %%
# F. **Validation** : vérifier qu’aucun `movieId` n’est dupliqué dans `movies`

total_movie = movies_df.count()
distinct_movieId = movies_df.select("movieId").distinct().count()

print(f"Nombre de films : {total_movie}")
print(f"Nombre d'id : {distinct_movieId}")
# Out:
# Nombre de films : 9742
# Nombre d'id : 9742
